# %%
import numpy as np
import cv2
import scipy.io
from matplotlib import pyplot as plt

mat_data = scipy.io.loadmat('C:/Users/debol/Downloads/GrayScaleMRI.mat')
original_image = mat_data['GrayScaleMRI']  
original_image = original_image.astype(np.uint8)

# Histogram Equalization
equalized_image = cv2.equalizeHist(original_image)

# Display images
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')

# Equalized image
plt.subplot(1, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')

plt.show()

# %%
import numpy as np
import cv2
import scipy.io
from matplotlib import pyplot as plt

mat_data = scipy.io.loadmat('C:/Users/debol/Downloads/geospatialImage.mat')
original_image = mat_data['Geospatial']  
original_image = original_image.astype(np.uint8)

# Histogram Equalization
equalized_image = cv2.equalizeHist(original_image)

# Display images
plt.figure(figsize=(10, 5))

# Original image
plt.subplot(1, 2, 1)
plt.imshow(original_image, cmap='gray')
plt.title('Original Image')

# Equalized image
plt.subplot(1, 2, 2)
plt.imshow(equalized_image, cmap='gray')
plt.title('Equalized Image')

plt.show()

# %%
mat_data = scipy.io.loadmat('C:/Users/debol/Downloads/geospatialImage.mat')
print("Keys in dictionary:", mat_data.keys())
# Out:
# Keys in dictionary: dict_keys(['__header__', '__version__', '__globals__', 'Geospatial'])
